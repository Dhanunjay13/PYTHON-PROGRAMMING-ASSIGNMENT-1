# %%
#Exercise 1: Prime Numbers
num=int(input("Enter a number:"))
if num>1:
    for i in range(2,num):
        if num%i==0:
            print(num,"number is not a prime number")
            break
    else:
            print(num,"Number is a prime ")
else:
    print("num is less than 1")
# Out:
# Enter a number: 6
# 6 number is not a prime number

# %%
#Exercise 2: Product of Random Numbers
import random
a=random.randint(1,10)
b=random.randint(1,10)
user=int(input(f" {a}*{b}"))
if user==a*b:
    print("correct answer",user)
else:
    print("wrong answer")
# Out:
#  2*8 16
# correct answer 16

# %%
#Exercise 3: Squares of Even/Odd Numbers
for num in range(101,201,2):
    print(num,"^2=",num**2)
# Out:
# 101 ^2= 10201
# 103 ^2= 10609
# 105 ^2= 11025
# 107 ^2= 11449
# 109 ^2= 11881
# 111 ^2= 12321
# 113 ^2= 12769
# 115 ^2= 13225
# 117 ^2= 13689
# 119 ^2= 14161
# 121 ^2= 14641
# 123 ^2= 15129
# 125 ^2= 15625
# 127 ^2= 16129
# 129 ^2= 16641
# 131 ^2= 17161
# 133 ^2= 17689
# 135 ^2= 18225
# 137 ^2= 18769
# 139 ^2= 19321
# 141 ^2= 19881
# 143 ^2= 20449
# 145 ^2= 21025
# 147 ^2= 21609
# 149 ^2= 22201
# 151 ^2= 22801
# 153 ^2= 23409
# 155 ^2= 24025
# 157 ^2= 24649
# 159 ^2= 25281
# 161 ^2= 25921
# 163 ^2= 26569
# 165 ^2= 27225
# 167 ^2= 27889
# 169 ^2= 28561
# 171 ^2= 29241
# 173 ^2= 29929
# 175 ^2= 30625
# 177 ^2= 31329
# 179 ^2= 32041
# 181 ^2= 32761
# 183 ^2= 33489
# 185 ^2= 34225
# 187 ^2= 34969
# 189 ^2= 35721
# 191 ^2= 36481
# 193 ^2= 37249
# 195 ^2= 38025
# 197 ^2= 38809
# 199 ^2= 39601

# %%
#Exercise 4:
#Problem Statement (Question): Hospital Billing System

room=2000*4
dr=1500
lab=300*3
medicine=2400
total=room+dr+lab+medicine
if total>10000:
    dis=total*0.10
else:
    dis=0
final=total-dis
print(final,"final")
# Out:
# 11520.0 final
